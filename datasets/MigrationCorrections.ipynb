# %%
import pandas as pd

# %%
df = pd.read_csv('Migration-Dataset - Sheet1.csv')

# %%
df
# Out:
#      Unnamed: 0                 date                Régions    Milieu  \
# 0             0  2014-01-01 00:00:00                Tunisie  Communal
# 1             1  2014-01-01 00:00:00                Tunisie  Communal
# 2             2  2014-01-01 00:00:00                Tunisie     Rural
# 3             3  2014-01-01 00:00:00                Tunisie     Rural
# 4             4  2014-01-01 00:00:00               Nord Est  Communal
# ..          ...                  ...                    ...       ...
# 691         111                  NaN   Gouvernorat de Gafsa     Rural
# 692         112                  NaN  Gouvernorat de Tozeur  Communal
# 693         113                  NaN  Gouvernorat de Tozeur  Communal
# 694         114                  NaN  Gouvernorat de Tozeur     Rural
# 695         115                  NaN  Gouvernorat de Tozeur     Rural
#
#          Sexe  raison  POPULATION
# 0    Masculin  Emploi       63996
# 1     Féminin  Emploi       30139
# ...

# %%
df['date'] = '2014-01-01 00:00:00'

# %%
df.tail()
# Out:
#      Unnamed: 0                 date                Régions    Milieu  \
# 691         111  2014-01-01 00:00:00   Gouvernorat de Gafsa     Rural
# 692         112  2014-01-01 00:00:00  Gouvernorat de Tozeur  Communal
# 693         113  2014-01-01 00:00:00  Gouvernorat de Tozeur  Communal
# 694         114  2014-01-01 00:00:00  Gouvernorat de Tozeur     Rural
# 695         115  2014-01-01 00:00:00  Gouvernorat de Tozeur     Rural
#
#          Sexe  raison  POPULATION
# 691   Féminin  Autres         159
# 692  Masculin  Autres          70
# 693   Féminin  Autres          62
# 694  Masculin  Autres           9
# 695   Féminin  Autres           7

# %%
df.to_csv('fin-migration.csv')
