# %%
import pandas as pd

# %%
df = pd.read_excel('mig.xlsx')

# %%
df
# Out:
#                      45973 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                  Régions     Milieu       Sexe       2014
# 1                  Régions     Milieu       Sexe     Emploi
# 2                  Tunisie   Communal   Masculin      63996
# 3                  Tunisie   Communal    Féminin      30139
# 4                  Tunisie      Rural   Masculin      15831
# ..                     ...        ...        ...        ...
# 113   Gouvernorat de Gafsa      Rural    Féminin        862
# 114  Gouvernorat de Tozeur   Communal   Masculin        630
# 115  Gouvernorat de Tozeur   Communal    Féminin        258
# 116  Gouvernorat de Tozeur      Rural   Masculin         97
# 117  Gouvernorat de Tozeur      Rural    Féminin         38
#
#                                             Unnamed: 4 Unnamed: 5  \
# 0                                                 2014       2014
# 1    Acquisition de logement ou meilleur condition ...    Mariage
# 2                                                73917      56323
# 3                                                48866      88487
# 4                                                 5089       9778
# ..                                                 ...        ...
# 113                                                295       1736
# 114                                                203        349
# 115                                                137        820
# 116                                                 35         79
# 117                                                 21        202
#
#                        Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0                            2014       2014       2014
# 1    Accompagnement de la famille     Etudes     Autres
# 2                           64224      19275      10346
# 3                          110390      16363       9653
# 4                            9662       2745       1030
# ..                            ...        ...        ...
# 113                          1702        609        159
# 114                           447        313         70
# 115                           738        206         62
# 116                            46         33          9
# 117                            67         24          7
#
# [118 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# 45973         0
# Unnamed: 1    0
# Unnamed: 2    0
# Unnamed: 3    0
# Unnamed: 4    0
# Unnamed: 5    0
# Unnamed: 6    0
# Unnamed: 7    0
# Unnamed: 8    0
# dtype: int64

# %% [markdown]
# #### Drop the first row

# %%
df.drop(0, inplace=True)

# %% [markdown]
# #### Rename  the columns

# %%
df.iloc[0].values
# Out:
# array(['Régions', 'Milieu', 'Sexe', 'Emploi',
#        'Acquisition de logement ou meilleur condition de vie', 'Mariage',
#        'Accompagnement de la famille', 'Etudes', 'Autres'], dtype=object)

# %%
df.columns = df.iloc[0].values

# %%
df.head()
# Out:
#    Régions    Milieu      Sexe  Emploi  \
# 1  Régions    Milieu      Sexe  Emploi
# 2  Tunisie  Communal  Masculin   63996
# 3  Tunisie  Communal   Féminin   30139
# 4  Tunisie     Rural  Masculin   15831
# 5  Tunisie     Rural   Féminin    8258
#
#   Acquisition de logement ou meilleur condition de vie  Mariage  \
# 1  Acquisition de logement ou meilleur condition ...    Mariage
# 2                                              73917      56323
# 3                                              48866      88487
# 4                                               5089       9778
# 5                                               3525      21046
#
#    Accompagnement de la famille  Etudes  Autres
# 1  Accompagnement de la famille  Etudes  Autres
# 2                         64224   19275   10346
# 3                        110390   16363    9653
# 4                          9662    2745    1030
# 5                         15931    2233    1220

# %%
df.drop(1,inplace=True)

# %% [markdown]
# #### Reset the indexes to start from 0

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Load the cleaned Data

# %%
df.head()
# Out:
#     Régions    Milieu      Sexe Emploi  \
# 0   Tunisie  Communal  Masculin  63996
# 1   Tunisie  Communal   Féminin  30139
# 2   Tunisie     Rural  Masculin  15831
# 3   Tunisie     Rural   Féminin   8258
# 4  Nord Est  Communal  Masculin  22067
#
#   Acquisition de logement ou meilleur condition de vie Mariage  \
# 0                                              73917     56323
# 1                                              48866     88487
# 2                                               5089      9778
# 3                                               3525     21046
# 4                                              46841     29627
#
#   Accompagnement de la famille Etudes Autres
# 0                        64224  19275  10346
# 1                       110390  16363   9653
# 2                         9662   2745   1030
# 3                        15931   2233   1220
# 4                        34307   6062   5402

# %%
df.to_excel('migration-dataset.xlsx')
